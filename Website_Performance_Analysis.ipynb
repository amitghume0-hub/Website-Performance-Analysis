# %%
#STEP 1= Data Cleaning

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\USER\Desktop\3RI\Analytics\Project\Website_Analysis/Website_performance_Analysis.csv") 
df.head() 

#yha pr jo header h usme unnamed1,unnamed2 aise aa rha h to uske liye hme 1st row ko header bnana hai so that we use df.iloc[0]
# Out:
#           # ----------------------------------------  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
#                  Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0  Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                2024041623        237        300               144
# 2                2024041719        208        267               132
# 3                2024041723        188        233               115
# 4                2024041718        187        256               125
#
#                             Unnamed: 5                 Unnamed: 6  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# ...

# %%
df.columns = df.iloc[0]
df = df.drop(index = 0).reset_index(drop = True)
df.columns = ["channel group","DateHour","Users","Sessions","Engaged Sessions","Average engagement time per session","Engaged sessions per user",	"Events per session",	"Engagement rate",	"Event count"]
df.head()
# Out:
#     channel group    DateHour Users Sessions Engaged Sessions  \
# 0          Direct  2024041623   237      300              144
# 1  Organic Social  2024041719   208      267              132
# 2          Direct  2024041723   188      233              115
# 3  Organic Social  2024041718   187      256              125
# 4  Organic Social  2024041720   175      221              112
#
#   Average engagement time per session Engaged sessions per user  \
# 0                  47.526666666666700        0.6075949367088610
# 1                   32.09737827715360        0.6346153846153850
# 2                   39.93991416309010        0.6117021276595740
# 3                         32.16015625        0.6684491978609630
# 4                  46.918552036199100                      0.64
#
#   Events per session      Engagement rate Event count
# 0  4.673333333333330                 0.48        1402
# 1  4.295880149812730   0.4943820224719100        1147
# ...

# %%
df.info()

#yha pr jo columns hai wo sare objects (string ) m hai to usko proper format me arrange krna h s
#hai uske liye niche code kiya h
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3182 non-null   object
#  1   DateHour                             3182 non-null   object
#  2   Users                                3182 non-null   object
#  3   Sessions                             3182 non-null   object
#  4   Engaged Sessions                     3182 non-null   object
#  5   Average engagement time per session  3182 non-null   object
#  6   Engaged sessions per user            3182 non-null   object
#  7   Events per session                   3182 non-null   object
#  8   Engagement rate                      3182 non-null   object
#  9   Event count                          3182 non-null   object
# dtypes: object(10)
# memory usage: 248.7+ KB

# %%
df["DateHour"] = pd.to_datetime(df["DateHour"], format = "%Y%m%d%H",errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3182 non-null   object
#  1   DateHour                             3182 non-null   datetime64[ns]
#  2   Users                                3182 non-null   object
#  3   Sessions                             3182 non-null   object
#  4   Engaged Sessions                     3182 non-null   object
#  5   Average engagement time per session  3182 non-null   object
#  6   Engaged sessions per user            3182 non-null   object
#  7   Events per session                   3182 non-null   object
#  8   Engagement rate                      3182 non-null   object
#  9   Event count                          3182 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 248.7+ KB

# %%
numeric_columns = df.columns.drop(["channel group","DateHour"])  #in dono ka datatype sahi hai isliye inko chhod k(so use drop) remaining col ka datatype numeric change kiya 
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric)       #To handle errors ,errors='coerce'
df['Hour'] = df["DateHour"].dt.hour          #Hour ka new Col add kiya hai

# %%
df.describe()
# Out:
#                             DateHour        Users     Sessions  \
# count                           3181  3181.000000  3181.000000
# mean   2024-04-20 01:18:31.348632576    41.874568    51.114429
# min              2024-04-06 00:00:00     0.000000     1.000000
# 25%              2024-04-13 02:00:00    20.000000    24.000000
# 50%              2024-04-20 02:00:00    42.000000    51.000000
# 75%              2024-04-26 22:00:00    60.000000    71.000000
# max              2024-05-03 23:00:00   208.000000   267.000000
# std                              NaN    29.383942    36.661139
#
#        Engaged Sessions  Average engagement time per session  \
# count       3181.000000                          3181.000000
# mean          28.289217                            66.650591
# min            0.000000                             0.000000
# 25%           13.000000                            32.097378
# 50%           27.000000                            49.040404
# ...

# %% [markdown]
# Sessions and user Over time

# %%
plt.figure(figsize=(13,5))
df.groupby("DateHour")[["Sessions","Users"]].sum().plot(ax=plt.gca())
plt.title("Sessions and users over time")
plt.xlabel("DateHour")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Total Users By Channel

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=df, x = "channel group", y = "Users", estimator = np.sum, palette = "viridis")
plt.title("Total users by Channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10668\42126986.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x = "channel group", y = "Users", estimator = np.sum, palette = "viridis")

# %% [markdown]
# #Average engagement time by Channel

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=df, x="channel group", y= "Average engagement time per session", estimator = np.mean,palette="magma")
plt.title("Avg Engagement Time by Channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10668\3701150778.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="channel group", y= "Average engagement time per session", estimator = np.mean,palette="magma")

# %%
df.head()
# Out:
#     channel group            DateHour  Users  Sessions  Engaged Sessions  \
# 0  Organic Social 2024-04-17 19:00:00    208       267               132
# 1          Direct 2024-04-17 23:00:00    188       233               115
# 2  Organic Social 2024-04-17 18:00:00    187       256               125
# 3  Organic Social 2024-04-17 20:00:00    175       221               112
# 4  Organic Social 2024-04-17 21:00:00    160       206               103
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            32.097378                   0.634615
# 1                            39.939914                   0.611702
# 2                            32.160156                   0.668449
# 3                            46.918552                   0.640000
# 4                            59.315534                   0.643750
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.295880         0.494382         1147    19
# ...

# %% [markdown]
# #Engagement rate distribution by channel

# %%
plt.figure(figsize = (10,4))
sns.boxplot(data = df,x = "channel group", y = "Engagement rate", palette = "magma")
plt.title("Engagement Rate Distribution by Channel")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10668\682258494.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data = df,x = "channel group", y = "Engagement rate", palette = "magma")

# %% [markdown]
# #Engaged vs non- engaged sessions

# %%
session_df = df.groupby("channel group")[["Sessions","Engaged Sessions"]].sum().reset_index()
session_df["Non-Engaged"]= session_df["Sessions"]-session_df["Engaged Sessions"]
session_df_melted = session_df.melt(id_vars = "channel group", value_vars = ["Engaged Sessions","Non-Engaged"])

plt.figure(figsize = (13,4))
sns.barplot(data = session_df_melted, x="channel group",y="value",hue = "variable")
plt.title("Engaged vs Non-Engaged sessions")
plt.xticks(rotation = 45)
plt.show()

# %%
df.head()
# Out:
#     channel group            DateHour  Users  Sessions  Engaged Sessions  \
# 0  Organic Social 2024-04-17 19:00:00    208       267               132
# 1          Direct 2024-04-17 23:00:00    188       233               115
# 2  Organic Social 2024-04-17 18:00:00    187       256               125
# 3  Organic Social 2024-04-17 20:00:00    175       221               112
# 4  Organic Social 2024-04-17 21:00:00    160       206               103
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            32.097378                   0.634615
# 1                            39.939914                   0.611702
# 2                            32.160156                   0.668449
# 3                            46.918552                   0.640000
# 4                            59.315534                   0.643750
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.295880         0.494382         1147    19
# ...

# %% [markdown]
# #Traffic by Hour and Channel

# %%
heatmap_data = df.groupby(["Hour","channel group"])["Sessions"].sum().unstack().fillna(0)

plt.figure(figsize = (13,8))
sns.heatmap(heatmap_data, cmap="YlGnBu",linewidths = 0.5, annot  = True,fmt= '0.0f')
plt.xlabel("Channel Group")
plt.ylabel("Hour of Day")
plt.show()

# %% [markdown]
# #Engagement Rate vs session over time

# %%
df_plot = df.groupby("DateHour")[["Engagement rate","Sessions"]].mean().reset_index()

plt.figure(figsize = (13,5))
plt.plot(df_plot["DateHour"], df_plot["Engagement rate"], label = "Engagement rate", color= "green")
plt.plot(df_plot["DateHour"], df_plot["Sessions"], label = "Sessions", color = "Blue")
plt.title("Engagement Rate vs Session Over Time")
plt.xlabel("DateHour")
plt.legend()
plt.grid(True)
plt.show()
